# %% [markdown]
# ![header.png](data:image/png;base64,...)

# %% [markdown]
# # Módulo X: Título del módulo o práctica
#
# **Diplomado en Ciencia de Datos para la Toma de Decisiones Estratégicas**
# **Universidad Pedagógica y Tecnológica de Colombia – UPTC**
# **Instructor:** [Nombre del docente]
# **Fecha:** [dd/mm/yyyy]
# **Sesión:** ##

# %% [markdown]
# ## Objetivos de aprendizaje
#
# ### 🎯 Objetivos
#
# - Objetivo 1
# - Objetivo 2
# - Objetivo 3

# %% [markdown]
# # Teoría
#
# ## Temáticas teóricas

# %% [markdown]
# ## Código
#
# ### Código computacional

# %%
# Importación de librerías esenciales
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Carga de Datos
#
# Explicación breve del dataset que se usará: fuente, variables clave, estructura.

# %%
# Carga de datos acá

# %% [markdown]
# ## Análisis Exploratorio de Datos (EDA)
#
# Incluir visualizaciones, estadísticas descriptivas y hallazgos preliminares.

# %%
# EDA acá

# %% [markdown]
# ## Modelado / Aplicación Analítica
#
# Explica y aplica el modelo o técnica (machine learning, clustering, predicción, etc.)

# %%
# código acá

# %% [markdown]
# ## Resultados y Visualización
#
# Incluir gráficas comparativas, métricas del modelo, insights clave.

# %%
# Aca puede ir codigo

# %% [markdown]
# o tambien puede ir texto

# %% [markdown]
# ##  Conclusiones
#
# - Insight 1
# - Insight 2
# - Recomendación basada en los resultados

# %% [markdown]
# ##  Bibliografía y Recursos
#
# - [Nombre del recurso](enlace)
# - Documentación oficial de librerías
# - Papers o artículos relacionados
# - Agregar al menos 1 fuente por sesión (se recomienda libros, repositorios o fuentes confiables como blogs de ciencia de datos).
